# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.analysis import load_clean_data, rfm_analysis, top_customers

# %% [markdown]
# # Business Insights

# %%
df = load_clean_data()

# %% [markdown]
# ## Top Customers by Revenue

# %%
top_customers(df)
# Out:
# CustomerID
# 14646.0    280206.02
# 18102.0    259657.30
# 17450.0    194550.79
# 16446.0    168472.50
# 14911.0    143825.06
# 12415.0    124914.53
# 14156.0    117379.63
# 17511.0     91062.38
# 16029.0     81024.84
# 12346.0     77183.60
# Name: TotalPrice, dtype: float64

# %% [markdown]
# A small group of customers drives large revenue.

# %% [markdown]
# ## RFM Analysis

# %%
rfm = rfm_analysis(df)

rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         325          1  77183.60
# 12347.0           1        182   4310.00
# 12348.0          74         31   1797.24
# 12349.0          18         73   1757.55
# 12350.0         309         17    334.40

# %% [markdown]
# RFM allows customer segmentation:
# - High value
# - Loyal
# - At risk
# - Churned

# %% [markdown]
# # Recommendations
#
# • Focus marketing on high-value customers
# • Promote best-selling products
# • Prepare for Q4 demand spikes
# • Expand strong international markets
